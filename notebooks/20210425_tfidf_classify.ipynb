# %% [markdown]
# # Classify with Content Features

# %%
from collections import OrderedDict
import sklearn
import pickle
import numpy as np
from pathlib import Path
import tqdm

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.feature_selection import RFE, SelectFromModel
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import ExtraTreesClassifier, RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC, LinearSVC
from sklearn.metrics import accuracy_score, f1_score

from utils import timed_func

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
with open("../data/text_classify_articles_with_arxiv.pkl", "rb") as f:
    data = pickle.load(f)

# %%
def fprint(s, outfile="20210425_export.out", end="\n"):
    with open(outfile, "a+") as f:
        f.write(s + end)

# %%
for conf in data.keys():
    conf_papers = len(data[conf])
    num_main = len([x for x in data[conf] if x['label'] == 1])
    num_workshop = len([x for x in data[conf] if x['label'] == 0])
    print(conf, conf_papers, num_main, num_workshop)
# Out:
# AAAI 466 430 36
# ACL 2543 1920 623
# COLING 1761 1412 349
# CVPR 3683 2609 1074
# EMNLP 552 442 110
# ICML 466 459 7
# ICRA 734 691 43
# IJCAI 674 468 206
# NAACL 2245 1091 1154
# NIPS 960 415 545

# %%
def process_vectorize(data, key="EMNLP", abstract=True, bodytext=True, max_features=1000):
    vectorizer = TfidfVectorizer(ngram_range=(1,2), max_features=max_features)
    texts = []
    labels = []
    for article in data[key]:
        article_text = []
        if abstract:
            article_text.append(article['abstract'])
        if bodytext:
            article_text.extend(article['bodytext'])
        texts.append(" ".join(article_text))
        
        labels.append(article['label'])
    X = vectorizer.fit_transform(texts)
    Y = np.array(labels)
    return X, Y, vectorizer.get_feature_names()

X, Y, feature_names = process_vectorize(data, 'EMNLP')
X.shape, Y.shape, feature_names[:10]
# Out:
# ((552, 1000),
#  (552,),
#  ['000', '10', '100', '11', '1993', '1994', '1995', '1996', '1997', '1998'])

# %%
def classify_select_models(XYF, models, verbose=True):
    """
    Same training scheme as 20210423_classify_select_features.ipynb
    """
    X, Y, feature_names = XYF
    
    skf = StratifiedKFold(n_splits=6)
    importances = []
    fold_accs = []
    fold_f1_scores = []
    best_model_names = []
    for trval_idx, test_idx in skf.split(X, Y):
        # Sweep through models in these folds. Choose the best one. Classify
        X_train, X_dev, Y_train, Y_dev = train_test_split(
            X[trval_idx], Y[trval_idx], test_size=0.2, stratify=Y[trval_idx]
        )
        X_test, Y_test = X[test_idx], Y[test_idx]
        f1_scores = []
        trained_models = []
        for model_name in models:
            model = sklearn.base.clone(models[model_name])
            try:
                model.fit(X_train, Y_train)
                Y_dev_pred = model.predict(X_dev)
                f1_scores.append(f1_score(Y_dev, Y_dev_pred))
            except ValueError:
                f1_scores.append(0)
            trained_models.append(model)
            
        
            
        max_id = np.argmax(f1_scores)
        model = trained_models[max_id]
        Y_test_pred = model.predict(X_test)
        fold_f1_scores.append(f1_score(Y_test, Y_test_pred))
        fold_accs.append(accuracy_score(Y_test, Y_test_pred))
    
        best_model_name = list(models.keys())[max_id]
        best_model_names.append(best_model_name)
    
        # Select the most important features
        selector = SelectFromModel(model)
        selector.fit(X[trval_idx], Y[trval_idx])
        if hasattr(model, "coef_"):
            importances.append(np.absolute(model.coef_[0]))
        elif hasattr(model, "feature_importances_"):
            importances.append(model.feature_importances_)
        else:
            pass  # Model doesn't support selecting features
        
    acc_mean, acc_std, f1_mean, f1_std = np.mean(fold_accs), np.std(fold_accs), np.mean(fold_f1_scores), np.std(fold_f1_scores)
    if len(importances) > 0:
        mean_imp = np.mean(importances, axis=0)
        top_features = np.array(feature_names)[np.argsort(-mean_imp)]
        top_features_str = "Top5 feats: " + "; ".join(top_features[:5])
    else:
        top_features = None
        top_features_str = ""
    
    if verbose:
        print("Acc: mean {:.4f}, std {:.4f}; F1: mean {:.4f}, std {:.4f}".format(
            acc_mean, acc_std, f1_mean, f1_std))
        print(top_features_str)
        
    fold_f1_scores_str = ", ".join(["{:.4f}".format(fs) for fs in fold_f1_scores])
    bm_str = ", ".join(best_model_names)
    return fold_f1_scores_str, top_features_str, bm_str
   
@timed_func
def select_features_sweep_params(XYF, verbose=True):
    models = OrderedDict({
        # Models that can select features:
        "linearsvc_l2_squared": LinearSVC(loss="squared_hinge", penalty="l2"),
        "linearsvc_l2_hinge": LinearSVC(loss="hinge", penalty="l2"),
        "logreg_default": LogisticRegression(max_iter=100, C=1.0),
        "logreg_maxiter200_C0.5": LogisticRegression(max_iter=200, C=0.5),
        "logreg_maxiter200_C1.0": LogisticRegression(max_iter=200, C=1.0),
        "logreg_maxiter200_C2.0": LogisticRegression(max_iter=200, C=2.0),
        "extratrees_16": ExtraTreesClassifier(n_estimators=16, random_state=0),
        "extratrees_32": ExtraTreesClassifier(n_estimators=32, random_state=0),
        "extratrees_64": ExtraTreesClassifier(n_estimators=64, random_state=0),
        "extratrees_128": ExtraTreesClassifier(n_estimators=128, random_state=0),
        "randomforest_50": RandomForestClassifier(n_estimators=50, random_state=0),
        "randomforest_100": RandomForestClassifier(n_estimators=100, random_state=0),
        "randomforest_200": RandomForestClassifier(n_estimators=200, random_state=0),
        "gb_depth2": GradientBoostingClassifier(max_depth=2), 
        "gb_depth3": GradientBoostingClassifier(max_depth=3), 
        "gb_depth4": GradientBoostingClassifier(max_depth=4),
        "gb_depth5": GradientBoostingClassifier(max_depth=5),
        
        # Models without support to selecting features:
        "mlp_10": MLPClassifier([10]),
        "mlp_20": MLPClassifier([20]),
        "mlp_40": MLPClassifier([40]),
        "mlp_80": MLPClassifier([80]),
        "mlp_10_10": MLPClassifier([10,10]),
        "mlp_20_20": MLPClassifier([20,20]),
        "mlp_20_20": MLPClassifier([40,40])
    })
    
    return classify_select_models(XYF, models, verbose)

#select_features_sweep_params((X, Y, feature_names))

# %%
def sweep_conditions():
    conditions = OrderedDict({
        "tfidf_abstract_bodytext_100": {"abstract": True, "bodytext": True, "max_features": 100},
        "tfidf_abstract_bodytext_300": {"abstract": True, "bodytext": True, "max_features": 300},
        "tfidf_abstract_bodytext_1k": {"abstract": True, "bodytext": True, "max_features": 1000},
        "tfidf_abstract_bodytext_3k": {"abstract": True, "bodytext": True, "max_features": 3000},
        "tfidf_abstract_100": {"abstract": True, "bodytext": False, "max_features": 100},
        "tfidf_abstract_300": {"abstract": True, "bodytext": False, "max_features": 300},
        "tfidf_abstract_1k": {"abstract": True, "bodytext": False, "max_features": 1000},
        "tfidf_bodytext_100": {"abstract": False, "bodytext": True, "max_features": 100},
        "tfidf_bodytext_300": {"abstract": False, "bodytext": True, "max_features": 300},
        "tfidf_bodytext_1k": {"abstract": False, "bodytext": True, "max_features": 1000},
    })
    for cond_name in conditions:
        print("="*20 + cond_name + "="*20)
        for key in data:
            print(key)
            X, Y, F = process_vectorize(data, key, **conditions[cond_name])
            f1_scores_str, top_feat_str, bm_str = select_features_sweep_params((X, Y, F))
            fprint(key+"_v_arxiv", end=", ")
            fprint(f1_scores_str, end=", ")
            fprint(top_feat_str, end=", ")
            fprint(bm_str, end=", ")
            fprint(cond_name)
            
sweep_conditions()
# Out:
# ====================tfidf_abstract_bodytext_100====================
# AAAI
# Acc: mean 0.9249, std 0.0049; F1: mean 0.9609, std 0.0025
# Top5 feats: is; are; algorithm; this; for
# select_features_sweep_params done in 26.55 seconds (0.01 hours)
# ACL
# Acc: mean 0.7731, std 0.0178; F1: mean 0.8629, std 0.0079
# Top5 feats: et; we; was; where; task
# select_features_sweep_params done in 163.96 seconds (0.05 hours)
# COLING
# Acc: mean 0.7973, std 0.0047; F1: mean 0.8860, std 0.0031
# Top5 feats: data; or; method; with; have
# select_features_sweep_params done in 103.46 seconds (0.03 hours)
# CVPR
# Acc: mean 0.7619, std 0.0091; F1: mean 0.8477, std 0.0042
# Top5 feats: we; et; our; al; where
# select_features_sweep_params done in 251.73 seconds (0.07 hours)
# EMNLP
# Acc: mean 0.8188, std 0.0136; F1: mean 0.8963, std 0.0078
# Top5 feats: where; al; than; section; as
# select_features_sweep_params done in 30.35 seconds (0.01 hours)
# ICML
# Acc: mean 0.9850, std 0.0048; F1: mean 0.9924, std 0.0024
# Top5 feats: of; the; each; training; we
# select_features_sweep_params done in 17.74 seconds (0.00 hours)
# ICRA
# Acc: mean 0.9414, std 0.0029; F1: mean 0.9698, std 0.0015
# Top5 feats: fig; that; was; network; of the
# select_features_sweep_params done in 32.78 seconds (0.01 hours)
# IJCAI
# Acc: mean 0.7612, std 0.0213; F1: mean 0.8390, std 0.0159
# Top5 feats: al; et; et al; state; where
# select_features_sweep_params done in 38.27 seconds (0.01 hours)
# NAACL
# Acc: mean 0.6632, std 0.0237; F1: mean 0.6508, std 0.0298
# Top5 feats: task; than; is; that; different
# select_features_sweep_params done in 137.64 seconds (0.04 hours)
# NIPS
# Acc: mean 0.6708, std 0.0241; F1: mean 0.6165, std 0.0283
# Top5 feats: et; al; section; that; performance
# select_features_sweep_params done in 58.78 seconds (0.02 hours)
# ====================tfidf_abstract_bodytext_300====================
# AAAI
# Acc: mean 0.9185, std 0.0189; F1: mean 0.9569, std 0.0102
# Top5 feats: was; of; we; algorithm; 2017
# select_features_sweep_params done in 49.69 seconds (0.01 hours)
# ACL
# Acc: mean 0.7794, std 0.0157; F1: mean 0.8663, std 0.0071
# Top5 feats: model; was; we; parsing; were
# select_features_sweep_params done in 336.94 seconds (0.09 hours)
# COLING
# Acc: mean 0.8035, std 0.0204; F1: mean 0.8855, std 0.0121
# Top5 feats: data; systems; based; for; algorithm
# select_features_sweep_params done in 209.55 seconds (0.06 hours)
# CVPR
# Acc: mean 0.7879, std 0.0102; F1: mean 0.8637, std 0.0044
# Top5 feats: et; note that; we; our; was
# select_features_sweep_params done in 590.61 seconds (0.16 hours)
# EMNLP
# Acc: mean 0.8188, std 0.0342; F1: mean 0.8974, std 0.0189
# Top5 feats: that; speech; 2004; the; in
# select_features_sweep_params done in 59.35 seconds (0.02 hours)
# ICML
# Acc: mean 0.9850, std 0.0048; F1: mean 0.9924, std 0.0024
# Top5 feats: network; of; model; nodes; we
# select_features_sweep_params done in 40.84 seconds (0.01 hours)
# ICRA
# Acc: mean 0.9387, std 0.0060; F1: mean 0.9684, std 0.0032
# Top5 feats: fig; cost; of the; surface; figure
# select_features_sweep_params done in 77.81 seconds (0.02 hours)
# IJCAI
# Acc: mean 0.7670, std 0.0176; F1: mean 0.8458, std 0.0075
# Top5 feats: al; et; al 2016; et al; reward
# select_features_sweep_params done in 71.70 seconds (0.02 hours)
# NAACL
# Acc: mean 0.7127, std 0.0219; F1: mean 0.6992, std 0.0204
# Top5 feats: search; problem; that; task; algorithm
# select_features_sweep_params done in 267.50 seconds (0.07 hours)
# NIPS
# Acc: mean 0.7125, std 0.0234; F1: mean 0.6517, std 0.0378
# Top5 feats: et; dataset; constant; use; network
# select_features_sweep_params done in 118.19 seconds (0.03 hours)
# ====================tfidf_abstract_bodytext_1k====================
# AAAI
# Acc: mean 0.9206, std 0.0090; F1: mean 0.9586, std 0.0048
# Top5 feats: language; goals; community; of; spatial
# select_features_sweep_params done in 95.75 seconds (0.03 hours)
# ACL
# Acc: mean 0.7971, std 0.0108; F1: mean 0.8760, std 0.0062
# Top5 feats: forms; 2008; task; 2011; 2014
# select_features_sweep_params done in 656.57 seconds (0.18 hours)
# COLING
# Acc: mean 0.8120, std 0.0100; F1: mean 0.8919, std 0.0065
# Top5 feats: shared; answer; annotator; etc; object
# select_features_sweep_params done in 463.81 seconds (0.13 hours)
# CVPR
# Acc: mean 0.8037, std 0.0042; F1: mean 0.8739, std 0.0025
# Top5 feats: et; et al; al; quality; loss
# select_features_sweep_params done in 1215.09 seconds (0.34 hours)
# EMNLP
# Acc: mean 0.8062, std 0.0254; F1: mean 0.8897, std 0.0151
# Top5 feats: ae; we; 2005; for; ae ae
# select_features_sweep_params done in 139.77 seconds (0.04 hours)
# ICML
# Acc: mean 0.9850, std 0.0048; F1: mean 0.9924, std 0.0024
# Top5 feats: network; key; of; model; embedding
# select_features_sweep_params done in 101.00 seconds (0.03 hours)
# ICRA
# Acc: mean 0.9414, std 0.0029; F1: mean 0.9698, std 0.0015
# Top5 feats: driving; fig; navigation; of the; user
# select_features_sweep_params done in 167.49 seconds (0.05 hours)
# IJCAI
# Acc: mean 0.8086, std 0.0163; F1: mean 0.8722, std 0.0128
# Top5 feats: al; 11; et; reward; al 2016
# select_features_sweep_params done in 161.23 seconds (0.04 hours)
# NAACL
# Acc: mean 0.7514, std 0.0058; F1: mean 0.7427, std 0.0084
# Top5 feats: 2015; semeval; 2010; 2009; 2002
# select_features_sweep_params done in 561.89 seconds (0.16 hours)
# NIPS
# Acc: mean 0.7448, std 0.0264; F1: mean 0.6954, std 0.0331
# Top5 feats: deep; et; 2014; dataset; 2012
# select_features_sweep_params done in 276.53 seconds (0.08 hours)
# ====================tfidf_abstract_bodytext_3k====================
# AAAI
# Acc: mean 0.9206, std 0.0088; F1: mean 0.9584, std 0.0047
# Top5 feats: communities; disease; emotion; diffusion; cognitive
# select_features_sweep_params done in 178.01 seconds (0.05 hours)
# ACL
# Acc: mean 0.7940, std 0.0155; F1: mean 0.8755, std 0.0096
# Top5 feats: we; hindi; parsing; model; was
# select_features_sweep_params done in 1131.19 seconds (0.31 hours)
# COLING
# Acc: mean 0.8154, std 0.0064; F1: mean 0.8942, std 0.0038
# Top5 feats: visual; shared task; qa; associations; association
# select_features_sweep_params done in 769.97 seconds (0.21 hours)
# CVPR
# Acc: mean 0.8075, std 0.0088; F1: mean 0.8749, std 0.0056
# Top5 feats: 2015; et; 2017; et al; appearance
# select_features_sweep_params done in 2237.23 seconds (0.62 hours)
# EMNLP
# Acc: mean 0.8043, std 0.0208; F1: mean 0.8886, std 0.0119
# Top5 feats: 2005; 1998; more; et al; assigned to
# select_features_sweep_params done in 220.95 seconds (0.06 hours)
# ICML
# Acc: mean 0.9850, std 0.0048; F1: mean 0.9924, std 0.0024
# Top5 feats: social; network; entities; functional; key
# select_features_sweep_params done in 157.63 seconds (0.04 hours)
# ICRA
# Acc: mean 0.9414, std 0.0029; F1: mean 0.9698, std 0.0015
# Top5 feats: trust; probabilistic; haptic; roadmap; fig
# select_features_sweep_params done in 287.93 seconds (0.08 hours)
# IJCAI
# Acc: mean 0.8042, std 0.0135; F1: mean 0.8672, std 0.0083
# Top5 feats: al; al 2016; 11; et al; et
# select_features_sweep_params done in 285.86 seconds (0.08 hours)
# NAACL
# Acc: mean 0.7505, std 0.0253; F1: mean 0.7440, std 0.0240
# Top5 feats: 2015; that; semeval; texts; document
# select_features_sweep_params done in 1003.34 seconds (0.28 hours)
# NIPS
# Acc: mean 0.7333, std 0.0216; F1: mean 0.6795, std 0.0208
# Top5 feats: et; al; et al; dataset; and
# select_features_sweep_params done in 461.98 seconds (0.13 hours)
# ====================tfidf_abstract_100====================
# AAAI
# Acc: mean 0.9184, std 0.0179; F1: mean 0.9573, std 0.0095
# Top5 feats: how; based; results; are; has
# select_features_sweep_params done in 15.01 seconds (0.00 hours)
# ACL
# Acc: mean 0.7621, std 0.0064; F1: mean 0.8588, std 0.0034
# Top5 feats: show; propose; system; paper; show that
# select_features_sweep_params done in 78.38 seconds (0.02 hours)
# COLING
# Acc: mean 0.7990, std 0.0043; F1: mean 0.8871, std 0.0036
# Top5 feats: data; of; for; languages; an
# select_features_sweep_params done in 55.93 seconds (0.02 hours)
# CVPR
# Acc: mean 0.7228, std 0.0049; F1: mean 0.8329, std 0.0039
# Top5 feats: between; using; each; our; problem
# select_features_sweep_params done in 170.05 seconds (0.05 hours)
# EMNLP
# Acc: mean 0.8025, std 0.0116; F1: mean 0.8896, std 0.0063
# Top5 feats: over; than; semantic; experiments; to the
# select_features_sweep_params done in 20.06 seconds (0.01 hours)
# ICML
# Acc: mean 0.9850, std 0.0048; F1: mean 0.9924, std 0.0024
# Top5 feats: networks; space; of; inference; models
# select_features_sweep_params done in 14.72 seconds (0.00 hours)
# ICRA
# Acc: mean 0.9387, std 0.0063; F1: mean 0.9683, std 0.0033
# Top5 feats: their; by; space; demonstrate; this
# select_features_sweep_params done in 21.55 seconds (0.01 hours)
# IJCAI
# Acc: mean 0.6869, std 0.0160; F1: mean 0.8074, std 0.0133
# Top5 feats: is; our; state of; each; set
# select_features_sweep_params done in 20.42 seconds (0.01 hours)
# NAACL
# Acc: mean 0.6450, std 0.0167; F1: mean 0.6297, std 0.0188
# Top5 feats: task; and; the; that; of
# select_features_sweep_params done in 63.20 seconds (0.02 hours)
# NIPS
# Acc: mean 0.6010, std 0.0303; F1: mean 0.5086, std 0.0217
# Top5 feats: deep; real; to the; be; for the
# select_features_sweep_params done in 38.71 seconds (0.01 hours)
# ====================tfidf_abstract_300====================
# AAAI
# Acc: mean 0.9249, std 0.0049; F1: mean 0.9608, std 0.0026
# Top5 feats: are; how; based; social; as
# select_features_sweep_params done in 18.02 seconds (0.01 hours)
# ACL
# Acc: mean 0.7747, std 0.0117; F1: mean 0.8682, std 0.0060
# Top5 feats: system; show; some; model; corpus
# select_features_sweep_params done in 87.13 seconds (0.02 hours)
# COLING
# Acc: mean 0.8018, std 0.0109; F1: mean 0.8892, std 0.0059
# Top5 feats: data; method; lexicon; languages; for
# select_features_sweep_params done in 61.29 seconds (0.02 hours)
# CVPR
# Acc: mean 0.7391, std 0.0116; F1: mean 0.8389, std 0.0056
# Top5 feats: using; deep learning; based; our method; previous
# select_features_sweep_params done in 155.65 seconds (0.04 hours)
# EMNLP
# Acc: mean 0.7935, std 0.0198; F1: mean 0.8842, std 0.0131
# Top5 feats: over; entropy; graph; lexical; with
# select_features_sweep_params done in 22.33 seconds (0.01 hours)
# ICML
# Acc: mean 0.9850, std 0.0048; F1: mean 0.9924, std 0.0024
# Top5 feats: network; networks; of; space; it is
# select_features_sweep_params done in 15.33 seconds (0.00 hours)
# ICRA
# Acc: mean 0.9387, std 0.0039; F1: mean 0.9684, std 0.0021
# Top5 feats: their; by; space; single; as
# select_features_sweep_params done in 26.62 seconds (0.01 hours)
# IJCAI
# Acc: mean 0.7137, std 0.0285; F1: mean 0.8174, std 0.0202
# Top5 feats: variables; on; sets; search; our
# select_features_sweep_params done in 26.11 seconds (0.01 hours)
# NAACL
# Acc: mean 0.6739, std 0.0278; F1: mean 0.6666, std 0.0243
# Top5 feats: semeval; neural; 2015; task; significantly
# select_features_sweep_params done in 72.79 seconds (0.02 hours)
# NIPS
# Acc: mean 0.6250, std 0.0298; F1: mean 0.5511, std 0.0249
# Top5 feats: deep; prediction; human; derive; case
# select_features_sweep_params done in 38.34 seconds (0.01 hours)
# ====================tfidf_abstract_1k====================
# AAAI
# Acc: mean 0.9141, std 0.0197; F1: mean 0.9550, std 0.0109
# Top5 feats: cognitive; how; stochastic; theory; social
# select_features_sweep_params done in 21.64 seconds (0.01 hours)
# ACL
# Acc: mean 0.7821, std 0.0165; F1: mean 0.8719, std 0.0089
# Top5 feats: system; task; show; paper describes; annotation
# select_features_sweep_params done in 106.89 seconds (0.03 hours)
# COLING
# Acc: mean 0.8024, std 0.0102; F1: mean 0.8882, std 0.0061
# Top5 feats: shared task; shared; concepts; semeval; data
# select_features_sweep_params done in 74.10 seconds (0.02 hours)
# CVPR
# Acc: mean 0.7630, std 0.0126; F1: mean 0.8508, std 0.0072
# Top5 feats: imaging; using; was; challenges; previous
# select_features_sweep_params done in 205.72 seconds (0.06 hours)
# EMNLP
# Acc: mean 0.7844, std 0.0146; F1: mean 0.8788, std 0.0094
# Top5 feats: methods; entropy; bilingual; tool; on
# select_features_sweep_params done in 27.90 seconds (0.01 hours)
# ICML
# Acc: mean 0.9850, std 0.0048; F1: mean 0.9924, std 0.0024
# Top5 feats: network; networks; relations; research; there
# select_features_sweep_params done in 20.81 seconds (0.01 hours)
# ICRA
# Acc: mean 0.9401, std 0.0036; F1: mean 0.9691, std 0.0019
# Top5 feats: users; by; maps; performance; space
# select_features_sweep_params done in 36.66 seconds (0.01 hours)
# IJCAI
# Acc: mean 0.7300, std 0.0090; F1: mean 0.8322, std 0.0085
# Top5 feats: search; reinforcement; sets; reinforcement learning; uncertainty
# select_features_sweep_params done in 34.64 seconds (0.01 hours)
# NAACL
# Acc: mean 0.6949, std 0.0262; F1: mean 0.6901, std 0.0339
# Top5 feats: neural; semeval; texts; 2015; building
# select_features_sweep_params done in 101.83 seconds (0.03 hours)
# NIPS
# Acc: mean 0.6385, std 0.0269; F1: mean 0.5234, std 0.0602
# Top5 feats: deep; networks; samples; human; lasso
# select_features_sweep_params done in 54.71 seconds (0.02 hours)
# ====================tfidf_bodytext_100====================
# AAAI
# Acc: mean 0.9227, std 0.0005; F1: mean 0.9598, std 0.0003
# Top5 feats: the; algorithm; this; and; al
# select_features_sweep_params done in 26.29 seconds (0.01 hours)
# ACL
# Acc: mean 0.7688, std 0.0099; F1: mean 0.8602, std 0.0063
# Top5 feats: each; model; where; was; task
# select_features_sweep_params done in 170.80 seconds (0.05 hours)
# COLING
# Acc: mean 0.7956, std 0.0062; F1: mean 0.8852, std 0.0043
# Top5 feats: our; data; set; some; with
# select_features_sweep_params done in 111.88 seconds (0.03 hours)
# CVPR
# Acc: mean 0.7635, std 0.0124; F1: mean 0.8500, std 0.0074
# Top5 feats: we; et; et al; our; al
# select_features_sweep_params done in 264.13 seconds (0.07 hours)
# EMNLP
# Acc: mean 0.8152, std 0.0198; F1: mean 0.8950, std 0.0119
# Top5 feats: we; the; in; and; model
# select_features_sweep_params done in 32.40 seconds (0.01 hours)
# ICML
# Acc: mean 0.9850, std 0.0048; F1: mean 0.9924, std 0.0024
# Top5 feats: of; each; training; the; algorithm
# select_features_sweep_params done in 19.12 seconds (0.01 hours)
# ICRA
# Acc: mean 0.9414, std 0.0029; F1: mean 0.9698, std 0.0015
# Top5 feats: fig; model; of the; network; learning
# select_features_sweep_params done in 36.41 seconds (0.01 hours)
# IJCAI
# Acc: mean 0.7878, std 0.0403; F1: mean 0.8541, std 0.0268
# Top5 feats: al; et; et al; first; where
# select_features_sweep_params done in 41.54 seconds (0.01 hours)
# NAACL
# Acc: mean 0.6677, std 0.0133; F1: mean 0.6553, std 0.0151
# Top5 feats: task; set; than; different; that
# select_features_sweep_params done in 157.73 seconds (0.04 hours)
# NIPS
# Acc: mean 0.6812, std 0.0382; F1: mean 0.6089, std 0.0505
# Top5 feats: et; al; section; learning; performance
# select_features_sweep_params done in 62.01 seconds (0.02 hours)
# ====================tfidf_bodytext_300====================
# AAAI
# Acc: mean 0.9227, std 0.0074; F1: mean 0.9597, std 0.0038
# Top5 feats: was; were; for; this; learning
# select_features_sweep_params done in 48.58 seconds (0.01 hours)
# ACL
# Acc: mean 0.7786, std 0.0121; F1: mean 0.8663, std 0.0072
# Top5 feats: we; 2008; was; et; et al
# select_features_sweep_params done in 341.01 seconds (0.09 hours)
# COLING
# Acc: mean 0.7950, std 0.0078; F1: mean 0.8846, std 0.0056
# Top5 feats: annotation; for; question; data; tree
# select_features_sweep_params done in 202.98 seconds (0.06 hours)
# CVPR
# Acc: mean 0.7847, std 0.0098; F1: mean 0.8627, std 0.0054
# Top5 feats: et; we; note that; our; 16
# select_features_sweep_params done in 566.09 seconds (0.16 hours)
# EMNLP
# Acc: mean 0.8116, std 0.0174; F1: mean 0.8941, std 0.0092
# Top5 feats: 2005; et al; al; than; 2004
# select_features_sweep_params done in 59.73 seconds (0.02 hours)
# ICML
# Acc: mean 0.9850, std 0.0048; F1: mean 0.9924, std 0.0024
# Top5 feats: network; of; we; nodes; are
# select_features_sweep_params done in 42.10 seconds (0.01 hours)
# ICRA
# Acc: mean 0.9414, std 0.0029; F1: mean 0.9698, std 0.0015
# Top5 feats: fig; path; of the; figure; with
# select_features_sweep_params done in 79.73 seconds (0.02 hours)
# IJCAI
# Acc: mean 0.7863, std 0.0183; F1: mean 0.8538, std 0.0138
# Top5 feats: al; reward; et; al 2016; et al
# select_features_sweep_params done in 75.92 seconds (0.02 hours)
# NAACL
# Acc: mean 0.6962, std 0.0226; F1: mean 0.6805, std 0.0259
# Top5 feats: task; algorithm; that; method; vector
# select_features_sweep_params done in 258.77 seconds (0.07 hours)
# NIPS
# Acc: mean 0.7125, std 0.0323; F1: mean 0.6467, std 0.0462
# Top5 feats: et; dataset; al; et al; samples
# select_features_sweep_params done in 121.87 seconds (0.03 hours)
# ====================tfidf_bodytext_1k====================
# AAAI
# Acc: mean 0.9141, std 0.0146; F1: mean 0.9547, std 0.0079
# Top5 feats: goals; in; agent; and; community
# select_features_sweep_params done in 101.18 seconds (0.03 hours)
# ACL
# Acc: mean 0.7798, std 0.0200; F1: mean 0.8666, std 0.0117
# Top5 feats: task; 2008; 2014; scheme; forms
# select_features_sweep_params done in 666.13 seconds (0.19 hours)
# COLING
# Acc: mean 0.8018, std 0.0109; F1: mean 0.8869, std 0.0090
# Top5 feats: annotation; answer; data; for; question
# select_features_sweep_params done in 454.64 seconds (0.13 hours)
# CVPR
# Acc: mean 0.8064, std 0.0083; F1: mean 0.8739, std 0.0053
# Top5 feats: we; et; neural; note that; processing
# select_features_sweep_params done in 1362.10 seconds (0.38 hours)
# EMNLP
# Acc: mean 0.8152, std 0.0198; F1: mean 0.8949, std 0.0111
# Top5 feats: 2005; 1998; more; than; al
# select_features_sweep_params done in 132.80 seconds (0.04 hours)
# ICML
# Acc: mean 0.9850, std 0.0048; F1: mean 0.9924, std 0.0024
# Top5 feats: network; key; of; model; embedding
# select_features_sweep_params done in 94.74 seconds (0.03 hours)
# ICRA
# Acc: mean 0.9414, std 0.0029; F1: mean 0.9698, std 0.0015
# Top5 feats: driving; fig; user; of the; navigation
# select_features_sweep_params done in 165.35 seconds (0.05 hours)
# IJCAI
# Acc: mean 0.8279, std 0.0191; F1: mean 0.8834, std 0.0111
# Top5 feats: al; 11; al 2016; et; et al
# select_features_sweep_params done in 159.51 seconds (0.04 hours)
# NAACL
# Acc: mean 0.7550, std 0.0147; F1: mean 0.7447, std 0.0186
# Top5 feats: 2010; 2015; 2005; embedding; algorithm
# select_features_sweep_params done in 581.70 seconds (0.16 hours)
# NIPS
# Acc: mean 0.7250, std 0.0284; F1: mean 0.6688, std 0.0320
# Top5 feats: et; et al; al; image; dataset
# select_features_sweep_params done in 259.63 seconds (0.07 hours)
